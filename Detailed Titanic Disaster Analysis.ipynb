# %%
# Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv(r"D:\Datasets\titanicdata.csv")

# %%
#Alternative way
df = pd.read_csv(r"titanic-data.csv")

# %%
# read top 5 records
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Data Understanding
# PassengerId - Sr. No of passangers
#
# Survived - Data of passengers if they are dead or alive
#
# Pclass - Passenger class
#
# Name - Name of passenger
#
# Sex - Sex of passanger
#
# Age - age of passanger on the ship
#
# SibSp - Sibliings and spouse travelling along with a particular passanger
#
# Parch - Parents or children travelling along with a particular passanger
#
# Ticket - Ticket number of a passanger
#
# Fare - Amount of money paid for the journey
#
# Cabin - Cabin/room number whih was allocated during the journey
#
# Embarked - Name of places from where passenger was onboarding (ports)

# %%
# getting information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Cleaning data
# 1) Keep Required columns
# 2) Data type of each column
# 3) Duplicate values
# 4) Fill the missing values
# 5) Checking wrong values

# %%
#Feature engineering part

# creating new column
df["Family"]= df["SibSp"]+df["Parch"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       1
# ...

# %% [markdown]
# Family - addition of sibsp and prach leads to create a whole family. In this way we have

# %%
# drop the unnecessary columns
df.drop(columns = ["SibSp","Parch","Ticket","Cabin"], axis=0,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#   Embarked  Family
# 0        S       1
# 1        C       1
# 2        S       0
# 3        S       1
# 4        S       0

# %%
#cheking the data type of each column
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# Fare           float64
# Embarked        object
# Family           int64
# dtype: object

# %% [markdown]
# The data types of all columns are in correct format. So no need to change any data type

# %%
#check if we have any duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We dont have any duplicate data

# %%
#if ever you have duplicated this is the syntax to delete
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (891, 9)

# %%
#Check the missing the missing values or nan values 
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# Fare             0
# Embarked         2
# Family           0
# dtype: int64

# %% [markdown]
# We found 2 missing values in column Embarked and 177 missing values into Age

# %% [markdown]
# Tip :  if u find 70%+ values are missing then delete that column

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked', 'Family'],
#       dtype='object')

# %%
mean= df["Age"].mean()
print(mean)
# Out:
# 29.69911764705882

# %%
pd.pivot_table(data =df, index = "Sex", columns =["Pclass"],values="Age", aggfunc="mean")
# Out:
# Pclass          1          2          3
# Sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %% [markdown]
# # Fill missing values

# %%
df["Age"].fillna(mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Fare           0
# Embarked       2
# Family         0
# dtype: int64

# %%
# simple method
mode = df["Embarked"].mode()[0]
df["Embarked"].fillna(mode)
df["Embarked"].isnull().sum()
# Out:
# 2

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# filtering the missing records
df[df["Embarked"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  Fare Embarked  Family
# 61   female  38.0  80.0      NaN       0
# 829  female  62.0  80.0      NaN       0

# %%
df[(df["Age"]>60) & (df["Survived"]==1)&(df["Pclass"]==1)&(df["Sex"]=='female')]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age     Fare Embarked  Family
# 275  female  63.0  77.9583        S       1
# 829  female  62.0  80.0000      NaN       0

# %% [markdown]
# Based on the above observation we can conclude that 829th record should be filled with "S" embarked

# %%
df[(df["Age"]==38)&(df["Survived"]==1)&(df["Pclass"]==1)&(df["Sex"]=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 61            62         1       1
# 716          717         1       1
#
#                                                   Name     Sex   Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 61                                 Icard, Miss. Amelie  female  38.0
# 716                      Endres, Miss. Caroline Louise  female  38.0
#
#          Fare Embarked  Family
# 1     71.2833        C       1
# 61    80.0000      NaN       0
# 716  227.5250        C       0

# %% [markdown]
# Based on the above observation we can conclude that 62nd record should be filled with "C" embarked

# %%
df["Embarked"].isnull().sum()
# Out:
# 2

# %%
#way1 
# filling null values using at function
df.at[61,"Embarked"]="C"

# %%
df.at[829,"Embarked"]="S"

# %%
df["Embarked"].isnull().sum()
# Out:
# 0

# %%
# way 2
#Filling missing values by creating a function
def fill_na(value):
    if value==61:
        df["Embarked"].fillna("C", inplace=True)
    elif value==829:
        df["Embarked"].fillna("S", inplace=True)
    else:
        return value

# %%
df["Embarked"].apply(fill_na)
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
#way3
# using fill na function for embarked column
df["Embarked"].fillna("C", inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# Family         0
# dtype: int64

# %%
df.iloc[100,6]
# Out:
# 7.8958

# %%
df.loc[100,"Fare"]
# Out:
# 7.8958

# %%
df.iloc[100,:]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# Fare                            7.8958
# Embarked                             S
# Family                               0
# Name: 100, dtype: object

# %%
df.loc[100,:]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# Fare                            7.8958
# Embarked                             S
# Family                               0
# Name: 100, dtype: object

# %%
df.iloc[:,5]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# non graphical ananlysis
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked', 'Family'],
#       dtype='object')

# %% [markdown]
# # graphical analysis
# 1) univariate ------ analysis for only one column
#
# 2) multivariate ----- a) bivariate ----- analysis wrt 2 columns
#
#                       b) multivariate ------- analysis for more than 2 columns

# %% [markdown]
# # Univariate Analysis
# As we can assume columns like'Survived', 'Pclass','Sex','Embarked', 'Family' contains categotical data, best way to represent such data will be a bar chart.
# Analysing each categorical columns for better understanding of data
#
# # Analysing the Survived column

# %%
df["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# There are only two unique values in Survived column.
#
# Where,
#
# 0 - passangers who are dead
#
# 1 - passangers who are alive

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.bar(df["Survived"].unique(),df["Survived"].value_counts(), tick_label=["0","1"])
plt.xlabel("Not Survived and Survived passangers")
plt.ylabel("Count")
plt.title("Count plot of survived passengers")
plt.show()

# %% [markdown]
# 549 passengers which makes approx 61% of passangers did not survived the distater
#
# where as 342 passangers survived the distater.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked', 'Family'],
#       dtype='object')

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# There are only three unique values in Pclass column.
#
# Where,
#
# 1 - passangers who belong from 1st class
#
# 2 - passangers who belong from 2nd class
#
# 3 - passangers who belong from 3rd class

# %% [markdown]
# # Analysis of Passanger class

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df = df.sort_values("Pclass")

# %%
df = df.sort_values("Pclass")
plt.bar(df["Pclass"].unique(),df["Pclass"].value_counts(), data = df, tick_label = ["3","1","2"])
plt.xlabel("Classes of passangers")
plt.ylabel("Count")
plt.title("Count plot of passengers from each class")
plt.show()

# %% [markdown]
# Around passangers 55% passangers which is maximum count belonged from third class
# Around passangers 24% passangers which is minimum count belonged from first class
#
# # Analysis of Gender column

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# There are only two unique values in Sex column ie male and female

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df = df.sort_values("Sex")
plt.bar(df["Sex"].unique(),df["Sex"].value_counts(), data = df, tick_label = ["male","female"])
plt.xlabel("Gender of passangers")
plt.ylabel("Count")
plt.title("Count plot of passengers from each gender")
plt.show()

# %% [markdown]
# Around 64% passsangers were male where as minority passangers were females.
#
# # Analysis of Embarked column

# %%
df["Embarked"].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %% [markdown]
# There are there unique values in Embarked column
# where S-Southampton, C-Cherbourg, and Q -Queenstown

# %%
df.Embarked.value_counts()
# Out:
# S    645
# C    169
# Q     77
# Name: Embarked, dtype: int64

# %%
df = df.sort_values("Embarked")
plt.bar(df["Embarked"].unique(),df["Embarked"].value_counts(), data = df, tick_label = ["S","C","Q"])
plt.xlabel("Port from which passangers have borded")
plt.ylabel("Count")
plt.title("Count plot of passengers from each embarked")
plt.show()

# %% [markdown]
# As we see 72% passangers boarded from S Embarked
# and least passagers ie less than 8% passangers boarded from Q port
#
# #  Analysis of Family column

# %%
df["Family"].unique()
# Out:
# array([ 2,  1,  0,  3,  4,  5,  6,  7, 10], dtype=int64)

# %%
df["Family"].unique().size
# Out:
# 9

# %%
df.Family.value_counts()
# Out:
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: Family, dtype: int64

# %% [markdown]
# There are 9 unique values in Family column which represent the size of a family.
# As we see there were no families of size 8 and 9.
# there is a possibilities that family size 10 might be outlier

# %%
df = df.sort_values("Family")
plt.bar(df["Family"].unique(),df["Family"].value_counts(), data = df, tick_label = ["0","1","2","3","5","4","6","10","7"])
plt.xlabel("Size of families")
plt.ylabel("Count")
plt.title("Count plot of family size")
plt.show()

# %% [markdown]
# Approx. 67% passangers were travelling with no family with them.
# Where as we can see less then 3% passangers were travelling along wih family where family size was greater than 3

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked', 'Family'],
#       dtype='object')

# %% [markdown]
# Previously we have studied about categorical columns. But where it comes to 'Age' or 'Fare' column we need to analyse the density of particular group.
# Hence for such clolumns histogram is the best type of visualisation.
#
# # Analysing Age column

# %%
df.Age.unique()
# Out:
# array([52.        , 35.        , 45.5       , 42.        , 51.        ,
#        25.        , 29.69911765, 39.        , 50.        , 29.        ,
#        36.        , 22.        , 21.        , 17.        , 32.        ,
#        24.        , 20.        , 38.        , 23.        , 28.        ,
#        34.        , 32.5       , 47.        , 54.        , 26.        ,
#        18.        , 14.        , 19.        , 40.        , 30.        ,
#        30.5       , 43.        , 33.        , 59.        , 16.        ,
#        55.        , 27.        , 62.        , 46.        , 31.        ,
#        45.        , 61.        , 48.        , 63.        , 66.        ,
#        20.5       , 41.        , 44.        , 58.        ,  5.        ,
#        49.        , 37.        , 74.        , 55.5       , 24.5       ,
#        28.5       , 57.        , 23.5       , 11.        , 71.        ,
#        64.        , 15.        , 56.        , 70.5       , 65.        ,
# ...

# %%
df.Age.unique().size
# Out:
# 89

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 24.500000      1
# 55.500000      1
# 74.000000      1
# 20.500000      1
# 0.920000       1
# Name: Age, Length: 89, dtype: int64

# %% [markdown]
# There are 89 different ages in which the passangers are classified.
# Passangers from 0 years upto 80 years were borded on ship.
# Out of which youth count of age near to 30 was found maximum ie 177 passangers.

# %% [markdown]
# # What is the average age of maximum passangers?

# %%
plt.figure(figsize=(10,4))
plt.hist(df["Age"], bins = 80)
plt.show()

# %% [markdown]
# 19% passangers were of age 29
#
# Hardly 1 passanger was belonging from age >70
#
# The density of age between 15 to 40 was maximum
#
# # Analysing Fare column

# %%
df.Fare.unique()
# Out:
# array([ 13.5   ,  26.2875,  28.5   ,  12.525 ,   7.65  ,   0.    ,
#         10.5   ,   9.5   ,  13.    ,   7.25  ,   8.05  ,   7.925 ,
#          7.125 ,  56.4958,   7.8958,   8.6625,  35.5   ,  52.    ,
#         51.8625,   7.8542,  33.    ,   8.1125,   9.    ,   7.775 ,
#          9.8417,   7.4958,   6.45  ,  10.5167,   7.8   , 151.55  ,
#         78.85  ,  86.5   ,  26.    ,  26.55  ,  15.    , 153.4625,
#         30.5   ,  42.4   ,   7.05  , 221.7792,  33.5   ,  34.0208,
#         31.    ,  30.    ,   8.6542,   9.5875,  16.    ,  14.    ,
#          9.8375,   7.5208,   7.7958,   7.75  ,   6.2375,  15.1   ,
#          7.1417,   9.35  ,  93.5   ,   7.55  ,   7.0542,   9.8458,
#         14.5   ,  16.1   ,   9.4833,   6.4958,   9.2167,   6.975 ,
#         24.15  ,   7.875 ,   9.225 ,  10.1708,  12.475 ,   8.85  ,
#         12.65  ,  77.9583,  25.9292,  22.525 ,  15.75  ,  80.    ,
#          8.6833, 135.6333,   8.3   , 211.3375,   7.8875,   8.4333,
# ...

# %%
df.Fare.unique().size
# Out:
# 248

# %%
df.Fare.min()
# Out:
# 0.0

# %%
df.Fare.min()
# Out:
# 0.0

# %%
df.Fare.max()
# Out:
# 512.3292

# %% [markdown]
# There are 248 unique fare amounts for the same journey.
# This amount varies for various classes and genders.
# The range of fare paid by passangers is from 0 to 512$
#
# But here paying 0$ might not be correct amount.
# Analysng the records of passangers who paid between 0$-1$

# %%
df[(df.Fare<5.0)].sort_index()
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 378          379         0       3               Betros, Mr. Tannous  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# ...

# %% [markdown]
# 1. All the passangers whose fare is 0 did not survive the disaster
# 2. All of them are male
# 3. All of them had embarked S
# 4. All were travelling alone
#
# Analysing the average fare based on above criteria to fill these values

# %%
pd.pivot_table(df, index= ["Family","Pclass"], columns=["Sex","Embarked","Survived"], 
               values="Fare").T
# Out:
# Family                            0                                 1   \
# Pclass                             1          2          3           1
# Sex    Embarked Survived
# female C        0          28.712500        NaN  14.458300         NaN
#                 1         123.541433  12.895850   7.227100   99.857021
#        Q        0                NaN        NaN   7.627783         NaN
#                 1                NaN  12.350000   7.795621   90.000000
#        S        0                NaN  12.166667   8.412244         NaN
#                 1          90.013333  14.176000   8.731250   85.796926
# male   C        0          59.163047  14.323600   7.955064   99.725000
#                 1          96.538550  13.862500   9.673340  134.995857
#        Q        0                NaN  12.350000   8.570215         NaN
#                 1                NaN        NaN   7.750000         NaN
#        S        0          34.024046  14.414754   8.793872   72.019792
# ...

# %% [markdown]
# According to the given criteria we found the average fare for each class and it is as follows
# 1. 1st class - 34.02
# 2. 2nd class - 14.41
# 3. 3rd class - 17.42
#
# Now let us fill these values in dataset

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked', 'Family'],
#       dtype='object')

# %%
idx = df[(df["Pclass"]==1)&(df['Survived']==0) & (df['Sex']=='male')&(df["Embarked"]=="S")&
         (df["Family"]==0)].index
df.loc[idx,"Fare"] = 34.02

# %%
idx = df[(df["Pclass"]==2)&(df['Survived']==0) & (df['Sex']=='male')&(df["Embarked"]=="S")&(df["Family"]==0)].index
df.loc[idx,"Fare"] = 14.41

# %%
idx = df[(df["Pclass"]==3) & (df['Sex']=='male')&(df["Embarked"]=="S")&(df["Family"]==0)].index
df.loc[idx,"Fare"] = 17.42

# %%
df[df.Fare<5.0]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age    Fare  \
# 378          379         0       3  Betros, Mr. Tannous  male  20.0  4.0125
#
#     Embarked  Family
# 378        C       0

# %% [markdown]
# # What is the avg fare of maximum passangers

# %%
plt.figure(figsize=(10,4))
plt.hist(df["Fare"], bins = 100)
plt.show()

# %% [markdown]
# As we can see from histogram that there is absolutely no value after 300 and hardly few records for 512 dollar
#
# Assuming that it is an outlier so, lets delete the records with value 512$

# %%
df[df.Fare>300]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age      Fare Embarked  Family
# 258  female  35.0  512.3292        C       0
# 737    male  35.0  512.3292        C       0
# 679    male  36.0  512.3292        C       1

# %%
df.drop(index=[737,258,679], axis=0,inplace=True)

# %%
plt.figure(figsize=(10,4))
plt.hist(df["Fare"], bins = 50)
plt.show()

# %% [markdown]
# Again as we can see there are few records for fare above 200 dollors.
# This is a suspecious fare. Analysing the ecords which are above 200

# %%
df[df.Fare>200]
# Out:
#      PassengerId  Survived  Pclass  \
# 730          731         1       1
# 557          558         0       1
# 380          381         1       1
# 716          717         1       1
# 700          701         1       1
# 299          300         1       1
# 118          119         0       1
# 779          780         1       1
# 689          690         1       1
# 377          378         0       1
# 311          312         1       1
# 742          743         1       1
# 341          342         1       1
# 438          439         0       1
# 27            28         0       1
# 88            89         1       1
#
#                                                   Name     Sex        Age  \
# 730                      Allen, Miss. Elisabeth Walton  female  29.000000
# 557                                Robbins, Mr. Victor    male  29.699118
# 380                              Bidois, Miss. Rosalie  female  42.000000
# ...

# %% [markdown]
# 1. All the passangers belonged to 1st class.
# 2. Fare is same for the same Family members.
#
# Hencer our assumption is wrong and fare above 200 is not outliers.

# %%
plt.figure(figsize=(10,4))
plt.hist(df["Fare"], bins = 10)
plt.show()

# %% [markdown]
# Maximum fare paid by passangers was between 5 dollors to 30$
# To be precise many passangers paid 32$ on average

# %% [markdown]
# # What was the range of Fare paid by each class?

# %%
plt.figure(figsize=(10,4))
sns.stripplot(data=df, x= "Fare", y="Pclass", hue="Sex")
plt.xticks(np.arange(0, 248, 10), rotation =90)
plt.show()

# %% [markdown]
# From the above graph it is very clear that
# 1. Passagners from 3rd class had lowest range of fare ie between 4 - 66$
# 2. Passagners from 2nd class had moderate range of fare ie between 10 - 78$
# 3. Passagners from 1st class had highest range of fare ie between 25 - 247$ and beyond
# Females from each clss were more fond of travelling.

# %% [markdown]
# # Multivariate analysis
#
# # How many passangers survived from each class?

# %%
sns.countplot(data =df, x="Pclass",hue="Survived",  palette =sns.color_palette())
plt.show()

# %% [markdown]
# 1. More than 350 Passangers from 3rd class have not survived the disaster where as less than 75 passangers died from 1st class
# As per the analysis due to heavy class system back in those day people of 3rd class were ignored from saving through this disaster and hence we can see third class people died the most
# 2. Out of 3 classes passangers belonging from 1st class survived the most which makes the count of more than 130
#
#
# # How many passangers survived from each gender?

# %%
sns.countplot(data =df, x="Sex",hue="Survived")
plt.show()

# %% [markdown]
# Female passangers survived the most as compared to male as females and children were saved on priority. Digging deep into the situation females from 1st class were maximum saviours.
#
# Approx 74% females survived from all female passangers who were onboarded
#
# Approx 81% males did not survived from all male passangers.
#
# # How many passangers survived from each embarked?

# %%
sns.countplot(data =df, x="Embarked",hue="Survived")
plt.show()

# %% [markdown]
# Passangers boarding from S port were one most affected as well as benifited passangers.
# Around 66.20% passangers were dead and 33.79% passangers were alive
# Where as 61% passangers were dead and 38.96% of passangers were saved from port Q
# But as we can see from graph port C shows reverse behaviour
# Only 45.18% of passangers died and 54.81% of passangers alive.
# More passangers survived as compared to the one who didnt from this Embarked C.
#
# # Why more passangers were affected from port S

# %%
df_embarked_S = df[(df.Embarked=="S")]

# %%
sns.countplot(data =df_embarked_S, x="Pclass",hue="Survived")
plt.show()

# %%
sns.countplot(data =df_embarked_S, x="Pclass",hue="Sex")
plt.show()

# %% [markdown]
# Passangers onboarded mostly from this Embarked hence the data of this Embarked shows maximum results of dead and survived passangers S compared to other two embarkes

# %%
plt.hist(x= "Fare", data= df_embarked_S, bins = 10)
plt.show()

# %% [markdown]
# As the previous graphs clearly states that 3ed class passangers were majorly onboarding from this port which leads to the point they had very less fare for the journey.
# Hence not only class system but also due to less fare people from 3rd class had to suffer the most

# %%
df_embarked_S[df_embarked_S["Fare"]==263]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 341          342         1       1  Fortune, Miss. Alice Elizabeth  female
# 438          439         0       1               Fortune, Mr. Mark    male
# 27            28         0       1  Fortune, Mr. Charles Alexander    male
# 88            89         1       1      Fortune, Miss. Mabel Helen  female
#
#       Age   Fare Embarked  Family
# 341  24.0  263.0        S       5
# 438  64.0  263.0        S       5
# 27   19.0  263.0        S       5
# 88   23.0  263.0        S       5

# %%
df_embarked_S["Fare"].min()
# Out:
# 6.4958

# %%
df_embarked_S[df_embarked_S["Fare"]<7]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 371          372         0       3  Wiklund, Mr. Jakob Alfred  male  18.0
#
#        Fare Embarked  Family
# 371  6.4958        S       1

# %% [markdown]
# Hence the above point is clear from the above results
#
# # Why least passangers were from port Q

# %%
df_embarked_Q = df[(df.Embarked=="Q")]
df_embarked_Q
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 208          209         1       3             Carr, Miss. Helen "Ellen"
# 767          768         0       3                    Mangan, Miss. Mary
# 626          627         0       2        Kirkland, Rev. Charles Leonard
# 790          791         0       3              Keane, Mr. Andrew "Andy"
# 697          698         1       3      Mullens, Miss. Katherine "Katie"
# ..           ...       ...     ...                                   ...
# 278          279         0       3                    Rice, Master. Eric
# 171          172         0       3                  Rice, Master. Arthur
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 16            17         0       3                  Rice, Master. Eugene
# 787          788         0       3             Rice, Master. George Hugh
#
#         Sex        Age     Fare Embarked  Family
# ...

# %%
sns.countplot(data =df_embarked_Q, x="Pclass",hue="Survived")
plt.show()

# %%
plt.hist(x= "Fare", data= df_embarked_Q, bins = 10)
plt.show()

# %%
df_embarked_Q[(df_embarked_Q.Fare<35)&(df_embarked_Q.Pclass==1)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, Fare, Embarked, Family]
# Index: []

# %% [markdown]
# 1. This Embarked is situated at very inconvient place hence not much 1st class people could travel till this embarked
# 2. As the average fare of this port was affordable for 2nd and 3rd class people they prefer to board from this port.
# Hence we dont have much passangers from this port
#
# # Why Embarked C shows reverse behaviour

# %%
df_embarked_C = df[(df.Embarked=="C")]
df_embarked_C
# Out:
#      PassengerId  Survived  Pclass  \
# 452          453         0       1
# 57            58         0       3
# 36            37         1       3
# 292          293         0       2
# 455          456         1       3
# ..           ...       ...     ...
# 469          470         1       3
# 608          609         1       2
# 685          686         0       2
# 311          312         1       1
# 742          743         1       1
#
#                                                   Name     Sex        Age  \
# 452                    Foreman, Mr. Benjamin Laventall    male  30.000000
# 57                                 Novel, Mr. Mansouer    male  28.500000
# 36                                    Mamee, Mr. Hanna    male  29.699118
# 292                             Levy, Mr. Rene Jacques    male  36.000000
# 455                                 Jalsevac, Mr. Ivan    male  29.000000
# ..                                                 ...     ...        ...
# ...

# %%
sns.countplot(data =df_embarked_C, x="Pclass",hue="Survived")
plt.show()

# %%
sns.countplot(data =df_embarked_C, x="Pclass",hue="Sex")
plt.show()

# %%
plt.hist(x= "Fare", data= df_embarked_C, bins = 10)
plt.show()

# %% [markdown]
# Similar to S Embarked many passengers from all the classes boarded from this port.
# But unlike other Embarked, females were in majority to onboard from this Embakrked and also as we know from above stripplot females end up paying more cost for journey.
# Here the histogram of Fare represents exactly same ie maximum fare amount.
# Hence this embarked bahved differently from other two.
#
# # How many passangers survived from each family?

# %%
sns.countplot(data =df, x="Family",hue="Survived")
plt.show()

# %% [markdown]
# Passangers with family size 0 were the most affected and saved category on the ship.
#
# out of all survived 32.2% were survived from the Family size 0
#
# Out of all non survivour 40.52% were not survived from faily size 0
#
# Where as over all,
#
# 48.38% passangers did not survived from any family sizes and
#
# 51.61% passangers survived from all family sizes
#
#
# # How many passangers of each gender belong from 3 different classes?

# %%
sns.countplot(data =df, x="Pclass",hue="Sex")
plt.show()

# %% [markdown]
# From all the three classes male were in majority as compared to female.
#
# Again if we see 42.62% ie majority % of male belonged to 3rd class
#
# From the graph Females from 3rd class were maximum which makes them 37.79% out of over all females
# From the previous observations the fare for 3rd class was least and hence that could be the reason we have highest number of passangers form 3rd class.
#
# # How many passangers of which gender belong from embarked

# %%
sns.countplot(data =df, x="Embarked",hue="Sex")
plt.show()

# %% [markdown]
# Many points from this graphs were stated above:
# eg:
# 1) S Embarked had most onboarding passangers
# 2) males were maximum as compared to females as the fare was comparatively less for males
#
#
# # Which family size has maximum passangers?

# %%
sns.countplot(data =df, x="Family",hue="Sex")
plt.show()

# %%
sns.countplot(data =df, x="Family",hue="Pclass")
plt.show()

# %%
sns.countplot(data =df, x="Family",hue="Embarked")
plt.show()

# %% [markdown]
# Single travellers were maximum irespective of gender, class, embarked.
#
# # Multivariate analysis
#
# # Which Gender of which class have to pay more and least?

# %%
sns.boxplot(x ="Fare", y = "Pclass", hue="Sex", orient="h", data =df )
plt.show()

# %% [markdown]
# 1. On an average first class had to pay maximum fare.
# 2. But again if we bifurcate on gender basis then women end up paying more cost than male.
# 3. 3rd class passangers paid leas fare for same travel.
# 4. Again male were paying negligible amount as comapred to females.
#
# # Which embarked charged higher amount for which gender?

# %%
sns.boxplot(x ="Fare", y = "Embarked", hue="Sex", orient="h", data =df )
plt.show()

# %% [markdown]
# Maximum fare paid by maximum passanger was below 100.
# Which states that maximum passangers belonged from 3rd class
# As per previous observations Embarked S and C had maximum passanges onboardeing from every class
# Hence the fare is distributed accordingly
# Also we know, Embarked Q had less passangers to onboard which were from 3rd class hence the fare was also least.
#
# # Classifying gender wise fare for each survival?

# %%
sns.boxplot(x ="Fare", y = "Survived", hue="Sex", orient="h", data =df )
plt.show()

# %% [markdown]
# As we already know females paid more fare as comapred to males.
# Makeing an insane connection passangers who paid more fare were the one who susrvived the most.
#
# # Survival wise fare for each class

# %%
sns.boxplot(x ="Fare", y = "Pclass", hue="Survived", orient="h", data =df )
plt.show()

# %% [markdown]
# As we know 1st class passangers paid more amount and hence they were given more prefrence for survival
# # Survival wise fare for each embarked?

# %%
sns.boxplot(x ="Fare", y = "Embarked", hue="Survived", orient="h", data =df )
plt.show()

# %%
# Survival wise fare for each family

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x ="Fare", y = "Family", hue="Survived", orient="h", data =df )
plt.show()

# %% [markdown]
# Passangers above family size 6 were from 3rd class and hence didn't survived.
# Passangers abover family size 3 were from mixed class but out of them those who belong to 3rd class did not survived the disaster.
#
# # Classwise fare for each gender

# %%
sns.boxplot(x ="Fare", y = "Pclass", hue="Sex", orient="h", data =df )
plt.show()

# %% [markdown]
# 1. Females ffrom 1st class paid avg fare of 80$
# 2. Males from 3rd class paid negligible fare
# 3. on an avg females paid more fare for travelling
#
# # Which Gender of which class had maximum youth?

# %%
plt.figure(figsize=(10,3))
sns.violinplot(x ="Pclass", y = "Age", hue="Sex", orient="v", data =df )
plt.show()

# %% [markdown]
# On an avereage every class and every genader wass having agerage age arounf the range of 25-35
# From the box plot males had more avg age than female passangers irrespective of class
# 1. maximum travellers were male from 1st class and the range of theor age is from below 0years to 80+ years
# 2. Where as the age range of females belonging from 1st class is from 1year to 70+ years
# 3. Same observations were seen in other two classes
#
# # Which embarked had higher age for which gender?

# %%
sns.violinplot(x ="Embarked", y = "Age", hue="Sex", orient="v", data =df )
plt.legend(loc="upper center")
plt.show()

# %%
df[(df["Embarked"]=="S")&(df["Sex"]=="male")&(df["Age"]>70)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age   Fare Embarked  Family
# 851  male  74.0  17.42        S       0
# 630  male  80.0  30.00        S       0

# %% [markdown]
# Highes age was recorded from S embarked of a male passanger named, Barkworth, Mr. Algernon Henry Wilson who was travelling alone and survived the disaster

# %%
df[(df["Embarked"]=="S")&(df["Sex"]=="female")&(df["Age"]>60)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
#
#         Sex   Age     Fare Embarked  Family
# 483  female  63.0   9.5875        S       0
# 829  female  62.0  80.0000        S       0
# 275  female  63.0  77.9583        S       1

# %% [markdown]
# Highes age in females was recorded from S embarked of 2 passangers from 1st class and 3rd class who named Andrews, Miss. Kornelia Theodosia	 and Turkula, Mrs. (Hedwig) respectively who were travelling eaither alone or with one family member survived the disaster
#
# # Classifying gender wise age for each survival?

# %%
sns.violinplot(x ="Sex", y = "Age", hue="Survived", orient="v", data =df )
plt.show()

# %%
# Survival wise age for each family
plt.figure(figsize=(12,3))
sns.violinplot(x ="Family", y = "Age", hue="Survived", orient="v", data =df )
plt.show()

# %% [markdown]
# As the family size increases the avg age of a particulr family size drops.

# %%
df[(df["Family"]==0)&(df["Age"]<16)].sort_index()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 731          732         0       3              Hassan, Mr. Houssein G N
# 777          778         1       3         Emanuel, Miss. Virginia Ethel
# 780          781         1       3                  Ayoub, Miss. Banoura
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age     Fare Embarked  Family
# 14   female  14.0   7.8542        S       0
# 22   female  15.0   8.0292        Q       0
# 731    male  11.0  18.7875        C       0
# 777  female   5.0  12.4750        S       0
# 780  female  13.0   7.2292        C       0
# 875  female  15.0   7.2250        C       0

# %% [markdown]
# 6 records seems to be abnormal as they are infacts or toddlers and have no famil member along with them.
# Hence finding out if there was anyone from the list who belongs to these children.
#
# As we an see all of them belonged from 3rd class hence shortlisting passangers from 3rd class from each embarked

# %%
df[(df["Pclass"]==3)&(df["Embarked"]=="Q")&(df["Family"]!=0)].sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 16            17         0       3
# 46            47         0       3
# 109          110         1       3
# 171          172         0       3
# 186          187         1       3
# 188          189         0       3
# 214          215         0       3
# 241          242         1       3
# 278          279         0       3
# 301          302         1       3
# 330          331         1       3
# 364          365         0       3
# 593          594         0       3
# 612          613         1       3
# 657          658         0       3
# 768          769         0       3
# 787          788         0       3
# 885          886         0       3
#
#                                                 Name     Sex        Age  \
# 16                              Rice, Master. Eugene    male   2.000000
# 46                                 Lennon, Mr. Denis    male  29.699118
# ...

# %% [markdown]
# No match found for passanger named McGowan, Miss. Anna "Annie".
# Also no match found for any other children.

# %%
df[(df["Pclass"]==3)&(df["Embarked"]=="C")&(df["Family"]!=0)].sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 39            40         1       3
# 48            49         0       3
# 65            66         1       3
# 73            74         0       3
# 111          112         0       3
# 125          126         1       3
# 128          129         1       3
# 140          141         0       3
# 240          241         0       3
# 255          256         1       3
# 352          353         0       3
# 362          363         0       3
# 381          382         1       3
# 448          449         1       3
# 469          470         1       3
# 532          533         0       3
# 533          534         1       3
# 578          579         0       3
# 620          621         0       3
# 622          623         1       3
# 644          645         1       3
# 691          692         1       3
# 702          703         0       3
# 709          710         1       3
# 803          804         1       3
# ...

# %%
No match found!

# %%
df[(df["Pclass"]==3)&(df["Embarked"]=="S")&(df["Family"]!=0)].sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# ..           ...       ...     ...
# 855          856         1       3
# 860          861         0       3
# 863          864         0       3
# 869          870         1       3
# 888          889         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 7                       Palsson, Master. Gosta Leonard    male   2.000000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.000000
# 13                         Andersson, Mr. Anders Johan    male  39.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# NO match found!

# %% [markdown]
# # Classwise Age for each survivour

# %%
plt.figure(figsize=(10,3))
sns.violinplot(x ="Survived", y = "Age", hue="Pclass", orient="v", data =df )
plt.show()

# %% [markdown]
# 1. The range of age of passangers who belong from1st class and did not survived the disaster was wide form 0-80years
# 2. The range of age of passangers who belong from 2nd class and did not survived the disaster was narrow form 10-70years
# 3. The range of age of passangers who belong from 3rd class and did not survived the disaster was wide same like 1st class also it had wide spread along the axis.
#
# Same observations were observed for survived category of passangers.

# %%
pivot_df = pd.pivot_table(df, index= "Pclass", columns=["Sex","Survived"], values="Age")
pivot_df

# %%
sns.heatmap(pivot_df, annot=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(df,hue="Survived")
plt.show()

# %% [markdown]
# Conclusion of analysis based on passangers who survived the disaster:
# As we have analysed the dataset, there were 891 passangers on the ship.
# 1. Out of all passangers 39% of passangers survived the disaster.
# 2. Out of which 28.37% belonged to 1st class the maximum survivours, due to class system 1st class passangers were given more prefrence than other classes.
# 3. As the analysis says 64% were Male passangers which is more than female passangers but due to prefrence of saving female passangers first 40.63% female passangers survived the disaster ie more female passangers were saved.
# 4. As per the class system 20.97% of female passsnagers were from first class , 17.11 % were from second class, and 17.51% were from third class
# 5. Average age of passangers was around 30 years and same was replicated for survived passangers
# 6. Passangers who paid more fare amount (ie 1st passangers) were saved in more amount as compared to others who paid less fare
# 7. Also we noted female passangers were always charged more fare and that can be reason we saw less female passangers as compared to male
# 8. The max fare for each class was 68$ for 3rd class, 77$ for 2nd class, and 263$ for 1st class passangers
# 9. Heavy onboarding was seen from S Embarked where passangers from all class, all gender and al age group were seen to get on ship. One reason might be easy to get to this port appropriate fare for each class Passangers.
# 10. Passangers from S enbarked were affected as well as saved more than any other port.
# 11. Similar sinario was observed from C Embarked but passsanger were saved more than those who were not saved because most of them belonged from 1st class category
# 12. Q embarked was very inconvienent to get and hence only 3rd class people were boarding from this port and most of them did not survived the disaster.
# 13. People travelling woth families paid paid more amount than people travelling alone.
#
# Keeping in mind the above analysis
# we can focus on reducing the fare for female passangers. Increase transport for Q port and promote travelling with families.
